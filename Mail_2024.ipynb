# %% [markdown]
# # Task 05 • Descriptive Statistics & LLM QA (SU Women’s Lacrosse 2024) -- part 2

# %%
def extract_text_from_pdfs():
    # Loading Documents:
    loader = DirectoryLoader("dataset_pdf/", glob="**/*.pdf")
    documents = loader.load()

    print(documents)

# %%
pip install "unstructured[pdf]"
# Out:
# Collecting unstructured[pdf]
#   Downloading unstructured-0.18.13-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: charset-normalizer in c:\users\manal\anaconda3\lib\site-packages (from unstructured[pdf]) (3.3.2)
# Requirement already satisfied: filetype in c:\users\manal\anaconda3\lib\site-packages (from unstructured[pdf]) (1.2.0)
# Requirement already satisfied: python-magic in c:\users\manal\anaconda3\lib\site-packages (from unstructured[pdf]) (0.4.27)
# Requirement already satisfied: lxml in c:\users\manal\appdata\roaming\python\python312\site-packages (from unstructured[pdf]) (5.2.2)
# Requirement already satisfied: nltk in c:\users\manal\anaconda3\lib\site-packages (from unstructured[pdf]) (3.9.1)
# Requirement already satisfied: requests in c:\users\manal\anaconda3\lib\site-packages (from unstructured[pdf]) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\manal\appdata\roaming\python\python312\site-packages (from unstructured[pdf]) (4.13.4)
# Collecting emoji (from unstructured[pdf])
#   Using cached emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# Collecting dataclasses-json (from unstructured[pdf])
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: python-iso639 in c:\users\manal\anaconda3\lib\site-packages (from unstructured[pdf]) (2025.2.18)
# Collecting langdetect (from unstructured[pdf])
#   Using cached langdetect-1.0.9-py3-none-any.whl
# Requirement already satisfied: numpy in c:\users\manal\anaconda3\lib\site-packages (from unstructured[pdf]) (1.26.4)
# Requirement already satisfied: rapidfuzz in c:\users\manal\anaconda3\lib\site-packages (from unstructured[pdf]) (3.13.0)
# Requirement already satisfied: backoff in c:\users\manal\appdata\roaming\python\python312\site-packages (from unstructured[pdf]) (2.2.1)
# Requirement already satisfied: typing-extensions in c:\users\manal\anaconda3\lib\site-packages (from unstructured[pdf]) (4.14.1)
# Collecting unstructured-client (from unstructured[pdf])
#   Downloading unstructured_client-0.42.3-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: wrapt in c:\users\manal\appdata\roaming\python\python312\site-packages (from unstructured[pdf]) (1.17.2)
# Requirement already satisfied: tqdm in c:\users\manal\anaconda3\lib\site-packages (from unstructured[pdf]) (4.66.5)
# Requirement already satisfied: psutil in c:\users\manal\appdata\roaming\python\python312\site-packages (from unstructured[pdf]) (7.0.0)
# Collecting python-oxmsg (from unstructured[pdf])
#   Using cached python_oxmsg-0.0.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: html5lib in c:\users\manal\appdata\roaming\python\python312\site-packages (from unstructured[pdf]) (1.1)
# Collecting onnx>=1.17.0 (from unstructured[pdf])
#   Using cached onnx-1.18.0-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: onnxruntime>=1.19.0 in c:\users\manal\appdata\roaming\python\python312\site-packages (from unstructured[pdf]) (1.21.0)
# Requirement already satisfied: pdf2image in c:\users\manal\anaconda3\lib\site-packages (from unstructured[pdf]) (1.17.0)
# Requirement already satisfied: pdfminer.six in c:\users\manal\anaconda3\lib\site-packages (from unstructured[pdf]) (20250506)
# Collecting pikepdf (from unstructured[pdf])
#   Using cached pikepdf-9.10.2-cp312-cp312-win_amd64.whl.metadata (8.2 kB)
# Requirement already satisfied: pi-heif in c:\users\manal\anaconda3\lib\site-packages (from unstructured[pdf]) (1.1.0)
# Requirement already satisfied: pypdf in c:\users\manal\anaconda3\lib\site-packages (from unstructured[pdf]) (6.0.0)
# Collecting google-cloud-vision (from unstructured[pdf])
#   Using cached google_cloud_vision-3.10.2-py3-none-any.whl.metadata (9.6 kB)
# Collecting effdet (from unstructured[pdf])
#   Using cached effdet-0.4.1-py3-none-any.whl.metadata (33 kB)
# Collecting unstructured-inference>=1.0.5 (from unstructured[pdf])
#   Using cached unstructured_inference-1.0.5-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: unstructured.pytesseract>=0.3.12 in c:\users\manal\anaconda3\lib\site-packages (from unstructured[pdf]) (0.3.15)
# Requirement already satisfied: protobuf>=4.25.1 in c:\users\manal\anaconda3\lib\site-packages (from onnx>=1.17.0->unstructured[pdf]) (6.31.1)
# Requirement already satisfied: coloredlogs in c:\users\manal\appdata\roaming\python\python312\site-packages (from onnxruntime>=1.19.0->unstructured[pdf]) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\manal\appdata\roaming\python\python312\site-packages (from onnxruntime>=1.19.0->unstructured[pdf]) (25.2.10)
# Requirement already satisfied: packaging in c:\users\manal\anaconda3\lib\site-packages (from onnxruntime>=1.19.0->unstructured[pdf]) (25.0)
# Requirement already satisfied: sympy in c:\users\manal\anaconda3\lib\site-packages (from onnxruntime>=1.19.0->unstructured[pdf]) (1.14.0)
# Requirement already satisfied: python-multipart in c:\users\manal\anaconda3\lib\site-packages (from unstructured-inference>=1.0.5->unstructured[pdf]) (0.0.20)
# Requirement already satisfied: huggingface-hub in c:\users\manal\anaconda3\lib\site-packages (from unstructured-inference>=1.0.5->unstructured[pdf]) (0.33.5)
# Collecting opencv-python!=4.7.0.68 (from unstructured-inference>=1.0.5->unstructured[pdf])
#   Using cached opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: matplotlib in c:\users\manal\appdata\roaming\python\python312\site-packages (from unstructured-inference>=1.0.5->unstructured[pdf]) (3.9.3)
# Requirement already satisfied: torch in c:\users\manal\anaconda3\lib\site-packages (from unstructured-inference>=1.0.5->unstructured[pdf]) (2.7.1)
# Collecting timm (from unstructured-inference>=1.0.5->unstructured[pdf])
#   Using cached timm-1.0.19-py3-none-any.whl.metadata (60 kB)
# Requirement already satisfied: transformers>=4.25.1 in c:\users\manal\anaconda3\lib\site-packages (from unstructured-inference>=1.0.5->unstructured[pdf]) (4.53.3)
# Collecting accelerate (from unstructured-inference>=1.0.5->unstructured[pdf])
#   Using cached accelerate-1.10.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: pandas in c:\users\manal\appdata\roaming\python\python312\site-packages (from unstructured-inference>=1.0.5->unstructured[pdf]) (2.3.1)
# Requirement already satisfied: scipy in c:\users\manal\anaconda3\lib\site-packages (from unstructured-inference>=1.0.5->unstructured[pdf]) (1.13.1)
# Requirement already satisfied: pypdfium2 in c:\users\manal\anaconda3\lib\site-packages (from unstructured-inference>=1.0.5->unstructured[pdf]) (4.30.0)
# Collecting numpy (from unstructured[pdf])
#   Using cached numpy-2.2.6-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: filelock in c:\users\manal\anaconda3\lib\site-packages (from transformers>=4.25.1->unstructured-inference>=1.0.5->unstructured[pdf]) (3.13.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\manal\anaconda3\lib\site-packages (from transformers>=4.25.1->unstructured-inference>=1.0.5->unstructured[pdf]) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\manal\anaconda3\lib\site-packages (from transformers>=4.25.1->unstructured-inference>=1.0.5->unstructured[pdf]) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\manal\anaconda3\lib\site-packages (from transformers>=4.25.1->unstructured-inference>=1.0.5->unstructured[pdf]) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\manal\anaconda3\lib\site-packages (from transformers>=4.25.1->unstructured-inference>=1.0.5->unstructured[pdf]) (0.5.3)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\manal\anaconda3\lib\site-packages (from huggingface-hub->unstructured-inference>=1.0.5->unstructured[pdf]) (2024.6.1)
# Requirement already satisfied: colorama in c:\users\manal\anaconda3\lib\site-packages (from tqdm->unstructured[pdf]) (0.4.6)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\manal\anaconda3\lib\site-packages (from unstructured.pytesseract>=0.3.12->unstructured[pdf]) (11.3.0)
# Requirement already satisfied: networkx in c:\users\manal\anaconda3\lib\site-packages (from torch->unstructured-inference>=1.0.5->unstructured[pdf]) (3.5)
# Requirement already satisfied: jinja2 in c:\users\manal\anaconda3\lib\site-packages (from torch->unstructured-inference>=1.0.5->unstructured[pdf]) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\manal\anaconda3\lib\site-packages (from torch->unstructured-inference>=1.0.5->unstructured[pdf]) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\manal\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.19.0->unstructured[pdf]) (1.3.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\manal\appdata\roaming\python\python312\site-packages (from beautifulsoup4->unstructured[pdf]) (2.7)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\manal\appdata\roaming\python\python312\site-packages (from coloredlogs->onnxruntime>=1.19.0->unstructured[pdf]) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\manal\appdata\roaming\python\python312\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.19.0->unstructured[pdf]) (3.5.4)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->unstructured[pdf])
#   Using cached marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\manal\anaconda3\lib\site-packages (from dataclasses-json->unstructured[pdf]) (0.9.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\manal\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured[pdf]) (1.0.0)
# Collecting torchvision (from effdet->unstructured[pdf])
#   Using cached torchvision-0.23.0-cp312-cp312-win_amd64.whl.metadata (6.1 kB)
# Collecting pycocotools>=2.0.2 (from effdet->unstructured[pdf])
#   Using cached pycocotools-2.0.10-cp312-abi3-win_amd64.whl.metadata (1.3 kB)
# Requirement already satisfied: omegaconf>=2.0 in c:\users\manal\anaconda3\lib\site-packages (from effdet->unstructured[pdf]) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in c:\users\manal\anaconda3\lib\site-packages (from omegaconf>=2.0->effdet->unstructured[pdf]) (4.9.3)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-vision->unstructured[pdf])
#   Using cached google_api_core-2.25.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in c:\users\manal\appdata\roaming\python\python312\site-packages (from google-cloud-vision->unstructured[pdf]) (2.38.0)
# Collecting proto-plus<2.0.0,>=1.22.3 (from google-cloud-vision->unstructured[pdf])
#   Using cached proto_plus-1.26.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\manal\appdata\roaming\python\python312\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-vision->unstructured[pdf]) (1.69.2)
# Collecting grpcio<2.0.0,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-vision->unstructured[pdf])
#   Using cached grpcio-1.74.0-cp312-cp312-win_amd64.whl.metadata (4.0 kB)
# Collecting grpcio-status<2.0.0,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-vision->unstructured[pdf])
#   Using cached grpcio_status-1.74.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\manal\appdata\roaming\python\python312\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[pdf]) (5.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\manal\appdata\roaming\python\python312\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[pdf]) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\manal\appdata\roaming\python\python312\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[pdf]) (4.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\manal\anaconda3\lib\site-packages (from requests->unstructured[pdf]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\manal\anaconda3\lib\site-packages (from requests->unstructured[pdf]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\manal\anaconda3\lib\site-packages (from requests->unstructured[pdf]) (2024.8.30)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\manal\appdata\roaming\python\python312\site-packages (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[pdf]) (0.6.0)
# Requirement already satisfied: six>=1.9 in c:\users\manal\appdata\roaming\python\python312\site-packages (from html5lib->unstructured[pdf]) (1.17.0)
# Requirement already satisfied: webencodings in c:\users\manal\appdata\roaming\python\python312\site-packages (from html5lib->unstructured[pdf]) (0.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\manal\anaconda3\lib\site-packages (from jinja2->torch->unstructured-inference>=1.0.5->unstructured[pdf]) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\manal\appdata\roaming\python\python312\site-packages (from matplotlib->unstructured-inference>=1.0.5->unstructured[pdf]) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\manal\appdata\roaming\python\python312\site-packages (from matplotlib->unstructured-inference>=1.0.5->unstructured[pdf]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\manal\appdata\roaming\python\python312\site-packages (from matplotlib->unstructured-inference>=1.0.5->unstructured[pdf]) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\manal\appdata\roaming\python\python312\site-packages (from matplotlib->unstructured-inference>=1.0.5->unstructured[pdf]) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\manal\appdata\roaming\python\python312\site-packages (from matplotlib->unstructured-inference>=1.0.5->unstructured[pdf]) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\manal\appdata\roaming\python\python312\site-packages (from matplotlib->unstructured-inference>=1.0.5->unstructured[pdf]) (2.9.0.post0)
# Requirement already satisfied: click in c:\users\manal\appdata\roaming\python\python312\site-packages (from nltk->unstructured[pdf]) (8.1.7)
# Requirement already satisfied: joblib in c:\users\manal\anaconda3\lib\site-packages (from nltk->unstructured[pdf]) (1.5.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\manal\appdata\roaming\python\python312\site-packages (from pandas->unstructured-inference>=1.0.5->unstructured[pdf]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\manal\appdata\roaming\python\python312\site-packages (from pandas->unstructured-inference>=1.0.5->unstructured[pdf]) (2025.2)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\manal\appdata\roaming\python\python312\site-packages (from pdfminer.six->unstructured[pdf]) (42.0.8)
# Requirement already satisfied: cffi>=1.12 in c:\users\manal\appdata\roaming\python\python312\site-packages (from cryptography>=36.0.0->pdfminer.six->unstructured[pdf]) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\manal\appdata\roaming\python\python312\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->unstructured[pdf]) (2.22)
# Requirement already satisfied: Deprecated in c:\users\manal\appdata\roaming\python\python312\site-packages (from pikepdf->unstructured[pdf]) (1.2.18)
# Requirement already satisfied: olefile in c:\users\manal\anaconda3\lib\site-packages (from python-oxmsg->unstructured[pdf]) (0.47)
# Collecting torch (from unstructured-inference>=1.0.5->unstructured[pdf])
#   Using cached torch-2.8.0-cp312-cp312-win_amd64.whl.metadata (30 kB)
# Collecting aiofiles>=24.1.0 (from unstructured-client->unstructured[pdf])
#   Using cached aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: httpcore>=1.0.9 in c:\users\manal\appdata\roaming\python\python312\site-packages (from unstructured-client->unstructured[pdf]) (1.0.9)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\manal\appdata\roaming\python\python312\site-packages (from unstructured-client->unstructured[pdf]) (0.28.1)
# Collecting pydantic>=2.11.2 (from unstructured-client->unstructured[pdf])
#   Using cached pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\manal\anaconda3\lib\site-packages (from unstructured-client->unstructured[pdf]) (1.0.0)
# Requirement already satisfied: h11>=0.16 in c:\users\manal\appdata\roaming\python\python312\site-packages (from httpcore>=1.0.9->unstructured-client->unstructured[pdf]) (0.16.0)
# Requirement already satisfied: anyio in c:\users\manal\appdata\roaming\python\python312\site-packages (from httpx>=0.27.0->unstructured-client->unstructured[pdf]) (4.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\manal\appdata\roaming\python\python312\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured[pdf]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\manal\anaconda3\lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured[pdf]) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\manal\anaconda3\lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured[pdf]) (0.4.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\manal\appdata\roaming\python\python312\site-packages (from anyio->httpx>=0.27.0->unstructured-client->unstructured[pdf]) (1.3.1)
# Downloading unstructured-0.18.13-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----------------------- ---------------- 1.0/1.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 6.9 MB/s  0:00:00
# Using cached onnx-1.18.0-cp312-cp312-win_amd64.whl (15.9 MB)
# Using cached unstructured_inference-1.0.5-py3-none-any.whl (48 kB)
# Using cached opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl (39.0 MB)
# Using cached numpy-2.2.6-cp312-cp312-win_amd64.whl (12.6 MB)
# Using cached accelerate-1.10.0-py3-none-any.whl (374 kB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Using cached effdet-0.4.1-py3-none-any.whl (112 kB)
# Using cached pycocotools-2.0.10-cp312-abi3-win_amd64.whl (76 kB)
# Using cached timm-1.0.19-py3-none-any.whl (2.5 MB)
# Using cached emoji-2.14.1-py3-none-any.whl (590 kB)
# Using cached google_cloud_vision-3.10.2-py3-none-any.whl (527 kB)
# Using cached google_api_core-2.25.1-py3-none-any.whl (160 kB)
# Using cached grpcio-1.74.0-cp312-cp312-win_amd64.whl (4.5 MB)
# Using cached grpcio_status-1.74.0-py3-none-any.whl (14 kB)
# Using cached proto_plus-1.26.1-py3-none-any.whl (50 kB)
# Using cached pikepdf-9.10.2-cp312-cp312-win_amd64.whl (3.7 MB)
# Using cached python_oxmsg-0.0.2-py3-none-any.whl (31 kB)
# Using cached torchvision-0.23.0-cp312-cp312-win_amd64.whl (1.6 MB)
# Using cached torch-2.8.0-cp312-cp312-win_amd64.whl (241.3 MB)
# Downloading unstructured_client-0.42.3-py3-none-any.whl (207 kB)
# Using cached aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Using cached pydantic-2.11.7-py3-none-any.whl (444 kB)
# Installing collected packages: proto-plus, numpy, marshmallow, langdetect, grpcio, emoji, aiofiles, torch, python-oxmsg, pydantic, pycocotools, pikepdf, opencv-python, onnx, grpcio-status, dataclasses-json, unstructured-client, torchvision, google-api-core, accelerate, unstructured, timm, unstructured-inference, google-cloud-vision, effdet
#
#   Attempting uninstall: numpy
#
#     Found existing installation: numpy None
#
#    - --------------------------------------  1/25 [numpy]
#
# Note: you may need to restart the kernel to use updated packages.
# error: uninstall-no-record-file
#
# × Cannot uninstall numpy None
# ╰─> The package's contents are unknown: no RECORD file was found for numpy.
#
# hint: You might be able to recover from this via: pip install --force-reinstall --no-deps numpy==1.26.4

# %%
pip uninstall onnxruntime
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pymupdf pandas
# Out:
# Requirement already satisfied: pymupdf in c:\users\manal\anaconda3\lib\site-packages (1.26.3)
# Requirement already satisfied: pandas in c:\users\manal\appdata\roaming\python\python312\site-packages (2.3.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\manal\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\manal\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\manal\appdata\roaming\python\python312\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\manal\appdata\roaming\python\python312\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\manal\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import fitz  # PyMuPDF
import pandas as pd

# Load the PDF
pdf_path = "dataset_pdf/2024SUStats.pdf"  # Replace with your path if different
doc = fitz.open(pdf_path)

# Extract all text
full_text = ""
for page in doc:
    full_text += page.get_text()

# Extract just the section between "Date" and "TEAM STATISTICS"
start_idx = full_text.find("Date")
end_idx = full_text.find("TEAM STATISTICS")
games_text = full_text[start_idx:end_idx]

# Split and clean lines
lines = [line.strip() for line in games_text.splitlines() if line.strip()]
lines_cleaned = lines[4:]  # Skip headers: "Date", "Opponent", "Score", "Att."
normalized_lines = [line.lstrip("*").strip() for line in lines_cleaned if line != "*"]

# Group every 5 lines into a match record
records = []
i = 0
while i + 4 < len(normalized_lines):
    try:
        date = normalized_lines[i]
        opponent = normalized_lines[i + 1]
        result = normalized_lines[i + 2]
        score = normalized_lines[i + 3]
        attendance = int(normalized_lines[i + 4])

        if '-' in score:
            su_score, opponent_score = map(int, score.split('-'))
        else:
            i += 1
            continue

        records.append([date, opponent, result, su_score, opponent_score, attendance])
        i += 5
    except Exception:
        i += 1  # Skip broken entries

# Create DataFrame and save to CSV
df = pd.DataFrame(records, columns=["Date", "Opponent", "Result", "SU_Score", "Opponent_Score", "Attendance"])
df.to_csv("SU_WLAX_2024_Results_AutoParsed.csv", index=False)

print("Saved to SU_WLAX_2024_Results_AutoParsed.csv")
print(df.head())
# Out:
# Saved to SU_WLAX_2024_Results_AutoParsed.csv
#      Date            Opponent Result  SU_Score  Opponent_Score  Attendance
# 0  Feb.10  at #1 Northwestern      L        15              18         933
# 1  Feb 14            #18 ARMY      W        18               7        1077
# 2  Feb 17         #9 MARYLAND  L o t         8               9        2097
# 3  Feb 24    at #2 Notre Dame      W        16              14         482
# 4  Mar 02                DUKE      W        15               8        1976

# %%
import fitz  # PyMuPDF
import pandas as pd
import re

# ---------- PDF ----------
PDF_PATH = "dataset_pdf/2024SUStats.pdf"   # change if needed
doc = fitz.open(PDF_PATH)
full_text = "".join(p.get_text() for p in doc)

# ---------- TEAM RECORD ----------
try:
    part = full_text.split("RECORD:", 1)[1].split("Date", 1)[0].strip().splitlines()
    data = [x.strip() for x in part if x.strip()]
    df_record = pd.DataFrame({
        "Category": ["All Games", "Conference", "Non-Conference"],
        "Overall": [data[5], data[9], data[13]],
        "Home":    [data[6], data[10], data[14]],
        "Away":    [data[7], data[11], data[15]],
        "Neutral": [data[8], data[12], data[16]],
    })
    df_record.to_csv("SU_Team_Record.csv", index=False)
except Exception as e:
    print("[WARN] Team record not parsed:", e)

# ---------- GAME RESULTS ----------
try:
    games_part = full_text.split("Date", 1)[1].split("TEAM STATISTICS", 1)[0]
    lines = [ln.strip().lstrip("*") for ln in games_part.splitlines() if ln.strip() and ln != "*"]
    lines = lines[4:]  # skip headers

    games, i = [], 0
    while i + 4 < len(lines):
        try:
            date, opponent, result, score, attend = lines[i:i+5]
            nums = list(map(int, re.findall(r"\d+", score)))
            su_sc, op_sc = (nums + [0, 0])[:2]
            attend = int(re.findall(r"\d+", attend)[0])
            games.append([date, opponent, result, su_sc, op_sc, attend])
            i += 5
        except Exception:
            i += 1

    pd.DataFrame(
        games,
        columns=["Date", "Opponent", "Result", "SU_Score", "Opponent_Score", "Attendance"]
    ).to_csv("SU_Game_Results_2024.csv", index=False)
except Exception as e:
    print("[WARN] Game results not parsed:", e)

# ---------- PERIOD TABLES (simple + robust) ----------
def _find_total_idx(nums):
    for i in range(5, min(len(nums), 8)):          # 1st–4th + optional OT/OT2
        if sum(nums[:i]) == nums[i]:
            return i
    return None

def _labels(n):
    base = ["1st", "2nd", "3rd", "4th"]
    if n >= 5: base.append("OT")
    if n >= 6: base.append("OT2")
    base.append("Total")
    return base

def _normalize(nums, want):
    if not nums:
        return [0]*want + [0]
    ti = _find_total_idx(nums)
    if ti is None:
        base = nums[:want]
        return base + [sum(base)]
    arr = nums[:ti+1]                 # include Total
    periods = len(arr) - 1
    if periods < want:                # pad before Total
        arr = arr[:-1] + [0]*(want - periods) + arr[-1:]
    elif periods > want:              # trim before Total
        arr = arr[:want] + [arr[-1]]
    arr[-1] = sum(arr[:-1])           # ensure Total is correct
    return arr

def _block_after(label):
    m = re.search(rf"{re.escape(label)}\s*(.+?)(?:\n\s*\n|$)", full_text, flags=re.DOTALL|re.IGNORECASE)
    return m.group(1) if m else None

def extract_stats_block(label, alt=None):
    blk = _block_after(label) or (_block_after(alt) if alt else None)
    if blk is None:
        raise ValueError(f"Block not found: {label}")

    def team_nums(team):
        m = re.search(rf"{team}.*", blk, flags=re.IGNORECASE)
        return list(map(int, re.findall(r"\d+", m.group(0)))) if m else None

    su = team_nums("Syracuse")
    opp = team_nums("Opponents")

    if su is None or opp is None:
        all_nums = list(map(int, re.findall(r"\d+", blk)))
        ti = _find_total_idx(all_nums) or (len(all_nums)//2 - 1)
        su = all_nums[:ti+1]
        opp = all_nums[ti+1:]

    want = max(4, min(6, len(su)-1), min(6, len(opp)-1))  # clamp 4..6
    labels = _labels(want)
    su = _normalize(su, want)
    opp = _normalize(opp, want)

    # final safety: align lengths
    m = min(len(labels), len(su), len(opp))
    return pd.DataFrame({"Period": labels[:m], "Syracuse": su[:m], "Opponents": opp[:m]})

# Parse and save
df_goals = extract_stats_block("Goals by Period")
df_saves = extract_stats_block("Saves by Period")
df_shots = extract_stats_block("Shots by Period")
df_sog   = extract_stats_block("Shots on Goal", alt="Shots on Goal by Period")

df_goals.to_csv("SU_Goals_By_Period_2024.csv", index=False)
df_saves.to_csv("SU_Saves_By_Period_2024.csv", index=False)
df_shots.to_csv("SU_Shots_By_Period_2024.csv", index=False)
df_sog.to_csv("SU_SOG_By_Period_2024.csv", index=False)

print("CSV files written.")
# Out:
# CSV files written.

# %%
import pandas as pd

# ✅ Make sure this line exists:
games = pd.read_csv("SU_Game_Results_2024.csv")

# ✅ Now this will work correctly
total_games = len(games)

# Win/Loss ratio
wins = len(games[games["Result"].str.startswith("W")])
losses = len(games[games["Result"].str.startswith("L")])
win_rate = wins / total_games

# Average score
avg_su_score = games["SU_Score"].mean()
avg_opp_score = games["Opponent_Score"].mean()

# Attendance insights
most_attended = games.sort_values("Attendance", ascending=False).head(3)

# Print summary
print(f"Games played: {total_games}, Wins: {wins}, Win %: {win_rate:.2f}")
print(f"Average SU Score: {avg_su_score:.2f}, Opponent Score: {avg_opp_score:.2f}")
print("Most attended games:\n", most_attended)
# Out:
# Games played: 21, Wins: 0, Win %: 0.00
# Average SU Score: 575.14, Opponent Score: 0.00
# Most attended games:
#             Date Opponent          Result  SU_Score  Opponent_Score  Attendance
# 2   #9 MARYLAND    L o t             8-9      2097               0          24
# 10         1238   Mar 30      LOUISVILLE         0               0          22
# 16          268   Apr 26  vs #6 Virginia         0               0          19

# %%
import pandas as pd
import os

# Load relevant CSV files
csv_files = {
    "game_results": "SU_Game_Results_2024.csv",
    "goals_by_period": "SU_Goals_By_Period_2024.csv",
    "saves_by_period": "SU_Saves_By_Period_2024.csv",
    "shots_by_period": "SU_Shots_By_Period_2024.csv",
    "sog_by_period": "SU_SOG_By_Period.csv",
    "team_record": "SU_Team_Record.csv"
}

# Load CSVs into dictionary
dataframes = {}
for key, file in csv_files.items():
    if os.path.exists(file):
        dataframes[key] = pd.read_csv(file)
    else:
        dataframes[key] = pd.DataFrame()

# Create stats summary dictionary
stats_summary = {}

# Team record stats
df_team = dataframes["team_record"]
if not df_team.empty:
    stats_summary["Total Games"] = df_team['Total Games'].sum() if 'Total Games' in df_team.columns else len(df_team)
    stats_summary["Wins"] = df_team['Wins'].sum() if 'Wins' in df_team.columns else None
    stats_summary["Losses"] = df_team['Losses'].sum() if 'Losses' in df_team.columns else None

# Goal statistics
df_goals = dataframes["goals_by_period"]
if not df_goals.empty:
    total_goals = df_goals.select_dtypes(include='number').sum().sum()
    stats_summary["Total Goals"] = total_goals
    stats_summary["Average Goals per Game"] = total_goals / len(df_goals)

# Save statistics
df_saves = dataframes["saves_by_period"]
if not df_saves.empty:
    total_saves = df_saves.select_dtypes(include='number').sum().sum()
    stats_summary["Total Saves"] = total_saves

# Shot statistics
df_shots = dataframes["shots_by_period"]
if not df_shots.empty:
    total_shots = df_shots.select_dtypes(include='number').sum().sum()
    stats_summary["Total Shots"] = total_shots
    if "Total Goals" in stats_summary:
        stats_summary["Shot Conversion Rate"] = stats_summary["Total Goals"] / total_shots

# Save percentage
if "Total Saves" in stats_summary and "Total Shots" in stats_summary:
    stats_summary["Save Percentage"] = stats_summary["Total Saves"] / stats_summary["Total Shots"]

# Convert to DataFrame and display
stats_df = pd.DataFrame(list(stats_summary.items()), columns=["Metric", "Value"])
display(stats_df)
# Out:
# C:\Users\manal\AppData\Local\Temp\ipykernel_19596\1031439173.py:51: RuntimeWarning: invalid value encountered in scalar divide
#   stats_summary["Shot Conversion Rate"] = stats_summary["Total Goals"] / total_shots
# C:\Users\manal\AppData\Local\Temp\ipykernel_19596\1031439173.py:55: RuntimeWarning: invalid value encountered in scalar divide
#   stats_summary["Save Percentage"] = stats_summary["Total Saves"] / stats_summary["Total Shots"]
#                    Metric  Value
# 0             Total Games    3.0
# 1                    Wins    NaN
# 2                  Losses    NaN
# 3             Total Goals    0.0
# 4  Average Goals per Game    0.0
# 5             Total Saves    0.0
# 6             Total Shots    0.0
# 7    Shot Conversion Rate    NaN
# 8         Save Percentage    NaN

# %% [markdown]
# ## LLM Evaluation Prompts (2024)
#
# Copy/paste into your LLM of choice (ChatGPT / Claude / Copilot). Provide the CSVs produced by this notebook as context.
#
# **Prompt A — Baseline sanity checks**
# - How many games did Syracuse play in 2024?
# - What was the overall record? Home/Away/Neutral splits?
# - Average goals scored vs allowed per game?
#
# **Prompt B — Deeper reasoning**
# - If the coach wants to win two more games next season, should the emphasis be offense or defense? Defend your answer with 2024 metrics (e.g., goals/shot quality, saves, shot clock violations, clears, turnovers).
# - Identify one player (if player-level data is available) or one phase (e.g., 1st vs 4th period) to prioritize. Explain the potential impact with evidence from 2024 stats.
#
# **Prompt C — Visualization requests**
# - Create a bar chart comparing goals, shots, and saves by period.
# - Plot goals scored vs allowed by game to spot trends or outliers.
#
# > After the LLM answers, validate each claim against the computed stats from this notebook. Record failures and fixes in your README.
